# %% [markdown]
# <a href="https://colab.research.google.com/github/DATA601-CustSegment-Nov2025-to-Feb2026/New-CustSegment-Project/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#testing

# %%
# 4th Testing

# %% [markdown]
# HELLO 123

# %%
# !git clone https://github.com/DATA601-CustSegment-Nov2025-to-Feb2026/New-CustSegment-Project
# Out:
# Cloning into 'New-CustSegment-Project'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 17 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 45.22 KiB | 3.48 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !git clone https://github.com/DATA601-CustSegment-Nov2025-to-Feb2026/New-CustSegment-Project
# Out:
# fatal: destination path 'New-CustSegment-Project' already exists and is not an empty directory.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd New-CustSegment-Project
# !git pull
# Out:
# /content/New-CustSegment-Project
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 891 bytes | 891.00 KiB/s, done.
# From https://github.com/DATA601-CustSegment-Nov2025-to-Feb2026/New-CustSegment-Project
#    bd5499f..401c4c5  main       -> origin/main
# Updating bd5499f..401c4c5
# Fast-forward
#  Testing.ipynb | 151 +++++++++++++++++++++++++++++++++-------------------------
#  1 file changed, 85 insertions(+), 66 deletions(-)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
